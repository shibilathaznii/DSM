# %%
import numpy as np
a = np.array ([[2,4],[6,3]])
b = np.array ([[5,6],[8,9]])
print("addition:",a+b)
print("substraction:",a-b)
print("multiplication:",a*b)
print("matrix multiplication:",np.dot(a,b))
print("transppose:",np.transpose(a))
# Out:
# addition: [[ 7 10]
#  [14 12]]
# substraction: [[-3 -2]
#  [-2 -6]]
# multiplication: [[10 24]
#  [48 27]]
# matrix multiplication: [[42 48]
#  [54 63]]
# transppose: [[2 6]
#  [4 3]]

# %%
import pandas as pd
a = {'rollno':[1,2,3],'name':['lina','diya','delna']}
b = pd.DataFrame(a)
print(b)
# Out:
#    rollno   name
# 0       1   lina
# 1       2   diya
# 2       3  delna

# %%
import pandas as pd
a = [1,2,3,4,5]
b = pd.Series(a)
print(b)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
import pandas as pd
a = {'rollno':[1,2,3],'name':['anu','lina','diya']}
b = pd.DataFrame(a)
print(b.loc[0])
# Out:
# rollno      1
# name      anu
# Name: 0, dtype: object

# %%
import pandas as pd
a=pd.read_csv('prm1.csv')
print(a.head(2))
# Out:
#    name subject place
# 0  diya     ads   clt
# 1  lima    dbms   mlp

# %%
import pandas as pd
a=pd.read_csv('prm1.csv')
print(a)
# Out:
#     name subject place
# 0   diya     ads   clt
# 1   lima    dbms   mlp
# 2   lina     dsa   clt
# 3  dilna     aos   mlp

# %%
import pandas as pd
a=pd.read_csv('prm1.csv')
print(a.tail(1))
# Out:
#     name subject place
# 3  dilna     aos   mlp

# %%
import pandas as pd
a=pd.read_csv('prm1.csv')
print(a)
b = a.dropna()
# Out:
#     name subject place
# 0   diya     ads   clt
# 1   lima    dbms   mlp
# 2   lina     dsa   clt
# 3  dilna     aos   mlp

# %%
import pandas as pd
a=pd.read_csv('prm1.csv')
print(a)
b = a.fillna()
# Out:
#     name subject place
# 0   diya     ads   clt
# 1   lima    dbms   mlp
# 2   lina     dsa   clt
# 3  dilna     aos   mlp
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16344/3440576867.py in <module>
#       2 a=pd.read_csv('prm1.csv')
#       3 print(a)
# ----> 4 b = a.fillna()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    5174         downcast=None,
#    5175     ) -> DataFrame | None:
# -> 5176         return super().fillna(
#    5177             value=value,
# ...

# %%
import pandas as pd
a = [1,7,2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
import pandas as pd
date_series = pd.date_range(start='2024-11-20',end = '2024-11-24')
print("Date Series:")
for date in date_series:
    print(date)
# Out:
# Date Series:
# 2024-11-20 00:00:00
# 2024-11-21 00:00:00
# 2024-11-22 00:00:00
# 2024-11-23 00:00:00
# 2024-11-24 00:00:00

# %%
import pandas as pd
data =[[101,'a',23],[102,'b',25],[103,'c',22]]
df = pd.DataFrame(data,columns = ['id','name','age'])
print("2d list to DataFrame:")
print(df)
# Out:
# 2d list to DataFrame:
#     id name  age
# 0  101    a   23
# 1  102    b   25
# 2  103    c   22

# %%
import pandas as pd

data = {"calories": [420, 380, 390], "duration": [50, 40, 45]}
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
import pandas as pd
df=pd.DataFrame({
    'roll':[1,2,3,4,5,6,7],
    'name':['a','b','c','d','e','f','g'],
    'marks':[78,82,90,65,85,92,70]
})
print("head of the DataFrame:")
print(df.head())
print("\ntail of the DataFrame:")
print(df.tail())
# Out:
# head of the DataFrame:
#    roll name  marks
# 0     1    a     78
# 1     2    b     82
# 2     3    c     90
# 3     4    d     65
# 4     5    e     85
#
# tail of the DataFrame:
#    roll name  marks
# 2     3    c     90
# 3     4    d     65
# 4     5    e     85
# 5     6    f     92
# 6     7    g     70

# %%
import pandas as pd

df = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['a', 'b', 'c', 'd'],
    'age': [20, 21, 19, 22]
})

selected_rows = df.iloc[[1, 3]]

print("Selected Rows:")
print(selected_rows)
# Out:
# Selected Rows:
#    id name  age
# 1   2    b   21
# 3   4    d   22

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'a':[10,np.nan,30],
    'b':[np.nan,50,60]
})
print("original DataFrame with NaN:")
print(df)
df_filled=df.fillna(0)
print("\nDataFrame after replacing NaN with 0:")
print(df_filled)
# Out:
# original DataFrame with NaN:
#       a     b
# 0  10.0   NaN
# 1   NaN  50.0
# 2  30.0  60.0
#
# DataFrame after replacing NaN with 0:
#       a     b
# 0  10.0   0.0
# 1   0.0  50.0
# 2  30.0  60.0
